# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

df = pd.read_csv("Active_bus_station_with_2022_data.csv")

gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df["Longitude"], df["Latitude"]),
    crs="EPSG:4326"
)

gdf
# Out:
#      Stop Code                                 Stop Name   Latitude  \
# 0         1072     Old Chapel Hill Rd at Garrett Rd (EB)  35.949715
# 1         1074       University Dr at American Red Cross  35.952773
# 2         1075           University Dr at Ivy Creek Blvd  35.959253
# 3         1105       Erwin Rd at Fulton St (VA Hospital)  36.008327
# 4         1406  Renaissance Pkwy at Southpoint Mall (WB)  35.903665
# ..         ...                                       ...        ...
# 834       6754                  Sima Ave at Ridgeway Ave  35.975890
# 835       6755                      Bacon St at Sima Ave  35.977233
# 836     995952                     Jackson St at Duke St  35.995417
# 837     996336                     Main St at Gregson St  35.999801
# 838     996511                 Holloway St at Dillard St  35.994771
#
#      Longitude  Status  Shelter Quantity Area_Light Trash Can  Site_Shade  \
# 0   -78.967443  Active               0.0       Good       NaN         NaN
# ...

# %%
gdf.plot(
    figsize=(10, 8),
    markersize=8
)

plt.title("Active Durham Bus Stops")
plt.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as cx

# Read CSV
df = pd.read_csv("Active_bus_station_with_2022_data.csv")

# Convert to GeoDataFrame
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(
        df["Longitude"],
        df["Latitude"]
    ),
    crs="EPSG:4326"
)

# Convert coordinate system for web maps
gdf = gdf.to_crs(epsg=3857)

# Plot
fig, ax = plt.subplots(figsize=(12,10))

gdf.plot(
    ax=ax,
    column="ADA Score",
    cmap="viridis",
    legend=True,
    markersize=20
)

# Add real basemap
cx.add_basemap(ax)

plt.title("Durham Bus Stops by ADA Score")
plt.axis("off")

plt.show()
