# %%
conda activate base
# Out:
# Error while loading conda entry point: conda-libmamba-solver (module 'libmambapy' has no attribute 'QueryFormat')
#
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install --force-reinstall numpy pandas -y
# Out:
# Error while loading conda entry point: conda-libmamba-solver (module 'libmambapy' has no attribute 'QueryFormat')
#
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda config --set solver classic
# Out:
# Error while loading conda entry point: conda-libmamba-solver (module 'libmambapy' has no attribute 'QueryFormat')

# %%
# !conda install geopandas -y
# Out:
# Error while loading conda entry point: conda-libmamba-solver (module 'libmambapy' has no attribute 'QueryFormat')
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::_anaconda_depends==2024.06=py312_openblas_2
#   - defaults/osx-arm64::jupyterlab_server==2.25.1=py312hca03da5_0
#   - defaults/osx-arm64::jupyterlab-variableinspector==3.1.0=py312hca03da5_0
#   - defaults/osx-arm64::anaconda-navigator==2.6.0=py312hca03da5_0
#   - defaults/osx-arm64::sphinx==7.3.7=py312hca03da5_0
#   - defaults/osx-arm64::widgetsnbextension==3.6.6=py312hca03da5_0
#   - defaults/osx-arm64::conda-build==24.5.1=py312hca03da5_0
#   - defaults/osx-arm64::aext-core-server==4.0.15=py312hca03da5_1
#   - defaults/osx-arm64::aext-core==4.0.15=py312hca03da5_jl4_0
#   - defaults/osx-arm64::aext-share-notebook==4.0.15=py312hca03da5_0
# ...

# %%
# !conda install --force-reinstall numpy pandas -y
# Out:
# Error while loading conda entry point: conda-libmamba-solver (module 'libmambapy' has no attribute 'QueryFormat')
# ^C
#
# CondaError: KeyboardInterrupt
